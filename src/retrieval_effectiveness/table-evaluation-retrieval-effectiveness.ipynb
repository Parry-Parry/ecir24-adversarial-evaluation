# %% [markdown]
# # Create the Table Evaluation Retrieval Effectiveness

# %%
import pandas as pd


df19 = pd.read_json('../../data/dl19-best-and-worst-case-evaluation.jsonl', lines=True, orient='records')
df19
# Out:
#                     name       map  recip_rank      P_10  ndcg_cut_10  map +  \
# 0        bm25 (original)  0.290678    0.795930  0.600000     0.481455    NaN
# 1       bm25 (best_case)  0.290678    0.795930  0.600000     0.481455    0.0
# 2      bm25 (worst_case)  0.290678    0.795930  0.600000     0.481455    0.0
# 3     colbert (original)  0.391702    0.926357  0.765116     0.679394    NaN
# 4    colbert (best_case)  0.427434    0.937984  0.825581     0.715697   40.0
# 5   colbert (worst_case)  0.376839    0.890310  0.730233     0.652680    3.0
# 6     electra (original)  0.458108    0.947674  0.830233     0.730119    NaN
# 7    electra (best_case)  0.488016    0.961240  0.865116     0.746237   40.0
# 8   electra (worst_case)  0.439636    0.932171  0.793023     0.708238    0.0
# 9          t5 (original)  0.437252    0.943798  0.832558     0.726904    NaN
# 10        t5 (best_case)  0.480565    0.959302  0.886047     0.756301   40.0
# 11       t5 (worst_case)  0.410807    0.916667  0.772093     0.683977    0.0
# 12       tasb (original)  0.412402    0.947674  0.804651     0.704276    NaN
# 13      tasb (best_case)  0.447531    0.959302  0.851163     0.736557   39.0
# 14     tasb (worst_case)  0.390037    0.919380  0.765116     0.676691    0.0
#
#     map -   map p-value  map reject  map p-value corrected  ...  P_10 +  \
# 0     NaN           NaN       False                    NaN  ...     NaN
# 1     0.0           NaN       False                    NaN  ...     0.0
# 2     0.0           NaN       False                    NaN  ...     0.0
# 3     NaN           NaN       False                    NaN  ...     NaN
# 4     0.0  5.400000e-09        True           1.630000e-08  ...    19.0
# 5    37.0  4.838000e-07        True           1.451400e-06  ...     2.0
# 6     NaN           NaN       False                    NaN  ...     NaN
# 7     0.0  9.000000e-10        True           2.700000e-09  ...    13.0
# 8    38.0  8.638000e-07        True           2.591500e-06  ...     0.0
# 9     NaN           NaN       False                    NaN  ...     NaN
# 10    0.0  6.000000e-10        True           1.700000e-09  ...    15.0
# 11   38.0  3.938000e-06        True           1.181390e-05  ...     0.0
# 12    NaN           NaN       False                    NaN  ...     NaN
# 13    0.0  1.600000e-09        True           4.700000e-09  ...    15.0
# 14   39.0  3.673000e-07        True           1.101900e-06  ...     0.0
#
#     P_10 -  P_10 p-value  P_10 reject  P_10 p-value corrected  ndcg_cut_10 +  \
# 0      NaN           NaN        False                     NaN            NaN
# 1      0.0           NaN        False                     NaN            0.0
# 2      0.0           NaN        False                     NaN            0.0
# 3      NaN           NaN        False                     NaN            NaN
# 4      0.0      0.000031         True                0.000093           27.0
# 5     13.0      0.004053         True                0.012159            3.0
# 6      NaN           NaN        False                     NaN            NaN
# 7      0.0      0.000255         True                0.000765           21.0
# 8     12.0      0.000581         True                0.001743            0.0
# 9      NaN           NaN        False                     NaN            NaN
# 10     0.0      0.000531         True                0.001594           24.0
# 11    16.0      0.000049         True                0.000148            0.0
# 12     NaN           NaN        False                     NaN            NaN
# 13     0.0      0.000427         True                0.001281           26.0
# 14    14.0      0.000152         True                0.000456            0.0
#
#     ndcg_cut_10 -  ndcg_cut_10 p-value  ndcg_cut_10 reject  \
# 0             NaN                  NaN               False
# 1             0.0                  NaN               False
# 2             0.0                  NaN               False
# 3             NaN                  NaN               False
# 4             8.0             0.000125                True
# 5            18.0             0.009308                True
# 6             NaN                  NaN               False
# 7             8.0             0.003317                True
# 8            20.0             0.000580                True
# 9             NaN                  NaN               False
# 10            8.0             0.000880                True
# 11           24.0             0.000050                True
# 12            NaN                  NaN               False
# 13            7.0             0.000169                True
# 14           24.0             0.000080                True
#
#     ndcg_cut_10 p-value corrected
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                        0.000375
# 5                        0.027925
# 6                             NaN
# 7                        0.009950
# 8                        0.001741
# 9                             NaN
# 10                       0.002640
# 11                       0.000149
# 12                            NaN
# 13                       0.000506
# 14                       0.000239
#
# [15 rows x 25 columns]

# %%
df20 = pd.read_json('../../data/dl20-best-and-worst-case-evaluation.jsonl', lines=True, orient='records')
df20
# Out:
#                     name       map  recip_rank      P_10  ndcg_cut_10  map +  \
# 0        bm25 (original)  0.314290    0.802359  0.575926     0.493627    NaN
# 1       bm25 (best_case)  0.314290    0.802359  0.575926     0.493627    0.0
# 2      bm25 (worst_case)  0.314290    0.802359  0.575926     0.493627    0.0
# 3     colbert (original)  0.435969    0.912522  0.725926     0.679899    NaN
# 4    colbert (best_case)  0.477623    0.946128  0.768519     0.721604   52.0
# 5   colbert (worst_case)  0.415368    0.885840  0.672222     0.642534    0.0
# 6     electra (original)  0.496005    0.953439  0.772222     0.748574    NaN
# 7    electra (best_case)  0.528481    0.957476  0.822222     0.774572   53.0
# 8   electra (worst_case)  0.465809    0.930401  0.735185     0.717489    0.0
# 9          t5 (original)  0.469411    0.951775  0.744444     0.712318    NaN
# 10        t5 (best_case)  0.514472    0.972222  0.822222     0.761604   54.0
# 11       t5 (worst_case)  0.432826    0.896484  0.688889     0.661302    0.0
# 12       tasb (original)  0.441617    0.920267  0.759259     0.693242    NaN
# 13      tasb (best_case)  0.483898    0.950176  0.818519     0.735718   53.0
# 14     tasb (worst_case)  0.415053    0.902160  0.688889     0.640325    0.0
#
#     map -   map p-value  map reject  map p-value corrected  ...  P_10 +  \
# 0     NaN           NaN       False                    NaN  ...     NaN
# 1     0.0           NaN       False                    NaN  ...     0.0
# 2     0.0           NaN       False                    NaN  ...     0.0
# 3     NaN           NaN       False                    NaN  ...     NaN
# 4     0.0  0.000000e+00        True           0.000000e+00  ...    18.0
# 5    51.0  1.900000e-09        True           5.800000e-09  ...     0.0
# 6     NaN           NaN       False                    NaN  ...     NaN
# 7     0.0  0.000000e+00        True           0.000000e+00  ...    21.0
# 8    54.0  2.580000e-08        True           7.740000e-08  ...     0.0
# 9     NaN           NaN       False                    NaN  ...     NaN
# 10    0.0  0.000000e+00        True           0.000000e+00  ...    30.0
# 11   52.0  6.100000e-09        True           1.830000e-08  ...     0.0
# 12    NaN           NaN       False                    NaN  ...     NaN
# 13    0.0  0.000000e+00        True           0.000000e+00  ...    21.0
# 14   53.0  5.000000e-10        True           1.600000e-09  ...     0.0
#
#     P_10 -  P_10 p-value  P_10 reject  P_10 p-value corrected  ndcg_cut_10 +  \
# 0      NaN           NaN        False                     NaN            NaN
# 1      0.0           NaN        False                     NaN            0.0
# 2      0.0           NaN        False                     NaN            0.0
# 3      NaN           NaN        False                     NaN            NaN
# 4      1.0  9.718390e-05         True            2.915516e-04           45.0
# 5     21.0  1.914920e-05         True            5.744750e-05            0.0
# 6      NaN           NaN        False                     NaN            NaN
# 7      0.0  4.652300e-06         True            1.395690e-05           32.0
# 8     15.0  1.138614e-04         True            3.415841e-04            0.0
# 9      NaN           NaN        False                     NaN            NaN
# 10     0.0  9.100000e-09         True            2.740000e-08           38.0
# 11    20.0  1.068900e-05         True            3.206700e-05            0.0
# 12     NaN           NaN        False                     NaN            NaN
# 13     0.0  1.194050e-05         True            3.582150e-05           38.0
# 14    26.0  9.790000e-08         True            2.937000e-07            0.0
#
#     ndcg_cut_10 -  ndcg_cut_10 p-value  ndcg_cut_10 reject  \
# 0             NaN                  NaN               False
# 1             0.0                  NaN               False
# 2             0.0                  NaN               False
# 3             NaN                  NaN               False
# 4             5.0         1.402410e-05                True
# 5            28.0         1.192680e-05                True
# 6             NaN                  NaN               False
# 7             9.0         2.612172e-04                True
# 8            29.0         1.916770e-05                True
# 9             NaN                  NaN               False
# 10           11.0         7.872000e-07                True
# 11           34.0         4.287100e-06                True
# 12            NaN                  NaN               False
# 13           11.0         1.167080e-04                True
# 14           33.0         1.785000e-07                True
#
#     ndcg_cut_10 p-value corrected
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                    4.207240e-05
# 5                    3.578050e-05
# 6                             NaN
# 7                    7.836516e-04
# 8                    5.750320e-05
# 9                             NaN
# 10                   2.361500e-06
# 11                   1.286130e-05
# 12                            NaN
# 13                   3.501241e-04
# 14                   5.355000e-07
#
# [15 rows x 25 columns]

# %%
def score(measure, approach, track):
    df = df19 if track == 'dl19' else df20

    l = df[df['name'] == approach]
    if len(l) != 1:
        raise ValueError(f'Expected one match, got {len(l)}')
    l = l.iloc[0].to_dict()
    significant = l[f'{measure} reject'] and 'original' not in approach

    return '{:.3f}'.format(l[measure]) + ('$^{*}$' if significant else '$\\phantom{^{*}}$')


def table_line(model):
    ret = []
    for track in ['dl19', 'dl20']:
        for measure in ['ndcg_cut_10', 'P_10']:
            for approach in [f'{model} (worst_case)', f'{model} (original)', f'{model} (best_case)']:
                ret += [score(measure, approach, track)]
    return ' & '.join(ret)

def table():
    return '''
\\begin{table*}[tb]
\\setlength{\\tabcolsep}{1.7pt}
\\renewcommand{\\arraystretch}{1.}
\\caption{The retrieval effectiveness when adversarial attacks are applied to only non-relevant documents (worst case), to no documents (original case), or to only relevant documents (best case). We report nDCG@10 and Precision@10. The asterisk $^{*}$ marks Bonferroni corrected significant changes to the original case without adversarial attacks.}
\\footnotesize
\\label{table-retrieval-effectiveness}
\\begin{tabular*}{\\textwidth}{@{}lcccccc@{\\quad}cccccc@{}}

    \\toprule
    
    & \\multicolumn{6}{@{}c@{}}{\\textbf{TREC DL 19}} & \\multicolumn{6}{@{}c@{}}{\\textbf{TREC DL 20}} \\\\
    
    \\cmidrule(r{20pt}){2-7} \\cmidrule(){8-13}
    & \\multicolumn{3}{@{}c@{}}{\\textbf{nDCG@10}} & \\multicolumn{3}{@{}c@{}}{\\textbf{Precision@10\\phantom{mm}}} & \\multicolumn{3}{@{}c@{}}{\\textbf{nDCG@10}} & \\multicolumn{3}{@{}c@{}}{\\textbf{Precision@10}} \\\\

    \\cmidrule(r{4pt}){2-4} \\cmidrule(r{20pt}){5-7} \\cmidrule(r{4pt}){8-10} \\cmidrule{11-13} 

    & Worst & Ori.\\ & Best & Worst & Ori.\\ & Best & Worst & Ori.\\ & Best & Worst & Ori.\\ & Best \\\\
    \\midrule

    BM25 & ''' + table_line('bm25') + ''' \\\\
    ColBERT & ''' + table_line('colbert') + ''' \\\\
    Electra & ''' + table_line('electra') + ''' \\\\
    MonoT5 & ''' + table_line('t5') + ''' \\\\
    TAS-B & ''' + table_line('tasb') + ''' \\\\

    \\bottomrule
\\end{tabular*}
\\end{table*}
 
'''

print(table())
# Out:
# \begin{table*}[tb]
# \setlength{\tabcolsep}{1.7pt}
# \renewcommand{\arraystretch}{1.}
# \caption{The retrieval effectiveness when adversarial attacks are applied to only non-relevant documents (worst case), to no documents (original case), or to only relevant documents (best case). We report nDCG@10 and Precision@10. The asterisk $^{*}$ marks Bonferroni corrected significant changes to the original case without adversarial attacks.}
# \footnotesize
# \label{table-retrieval-effectiveness}
# \begin{tabular*}{\textwidth}{@{}lcccccc@{\quad}cccccc@{}}
#
#     \toprule
#
#     & \multicolumn{6}{@{}c@{}}{\textbf{TREC DL 19}} & \multicolumn{6}{@{}c@{}}{\textbf{TREC DL 20}} \\
#
#     \cmidrule(r{20pt}){2-7} \cmidrule(){8-13}
#     & \multicolumn{3}{@{}c@{}}{\textbf{nDCG@10}} & \multicolumn{3}{@{}c@{}}{\textbf{Precision@10\phantom{mm}}} & \multicolumn{3}{@{}c@{}}{\textbf{nDCG@10}} & \multicolumn{3}{@{}c@{}}{\textbf{Precision@10}} \\
#
#     \cmidrule(r{4pt}){2-4} \cmidrule(r{20pt}){5-7} \cmidrule(r{4pt}){8-10} \cmidrule{11-13}
#
#     & Worst & Ori.\ & Best & Worst & Ori.\ & Best & Worst & Ori.\ & Best & Worst & Ori.\ & Best \\
#     \midrule
#
#     Electra & 0.711$^{*}$ & 0.730$\phantom{^{*}}$ & 0.743$\phantom{^{*}}$ & 0.795$^{*}$ & 0.830$\phantom{^{*}}$ & 0.856$^{*}$ & --- & --- & --- & --- & --- & --- \\
#     MonoT5 & 0.669$^{*}$ & 0.727$\phantom{^{*}}$ & 0.755$^{*}$ & 0.742$^{*}$ & 0.833$\phantom{^{*}}$ & 0.891$^{*}$ & --- & --- & --- & --- & --- & --- \\
#
#     \bottomrule
# \end{tabular*}
# \end{table*}
